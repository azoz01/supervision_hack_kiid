# %%
import os
os.chdir("..")

# %%
import pandas as pd
from lib.constants import KIID_DATA_PATH

# %%
df = pd.read_csv(KIID_DATA_PATH)
df["IDENTYFIKATOR_KRAJOWY"]
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: IDENTYFIKATOR_KRAJOWY, dtype: float64

# %%
df
# Out:
#    ID_KIID  ID_ZESPOLU                                  NAZWA_SUBFUNDUSZU  \
# 0      520           2                                                NaN
# 1      109           2  Amundi Subfundusz Globalnych Perspektyw Dynami...
# 2      412           2                                                NaN
# 3      394           2                                                NaN
# 4       54           2                                                NaN
# 5      323           2             Rockbridge Subfundusz Gier i Innowacji
#
#                                       NAZWA_FUNDUSZU  ISIN  \
# 0                                                NaN   NaN
# 1                                                NaN   NaN
# 2                                                NaN   NaN
# 3               Allianz Fundusz Inwestycyjny Otwarty   NaN
# 4                                                NaN   NaN
# 5  Rockbridge Fundusz Inwestycyjny Otwarty Paraso...   NaN
#
# ...
