# %%
import os
os.chdir("..")

# %%
import pandas as pd
from lib.constants import KIID_DATA_PATH

# %%
df = pd.read_csv(KIID_DATA_PATH)
df["IDENTYFIKATOR_KRAJOWY"]
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: IDENTYFIKATOR_KRAJOWY, dtype: float64

# %%
df
# Out:
#    ID_KIID  ID_ZESPOLU                                  NAZWA_SUBFUNDUSZU  \
# 0      134           2                                                NaN
# 1      242           2  Amundi Subfundusz Globalnych Perspektyw Konser...
# 2       18           2                                                NaN
# 3      227           2                             Generali Horyzont 2055
# 4      123           2                             Generali Horyzont 2025
# 5      459           2                                                NaN
#
#                                       NAZWA_FUNDUSZU  ISIN  \
# 0                                                NaN   NaN
# 1                                                NaN   NaN
# 2  BNP Paribas PPK Specjalistyczny Fundusz Inwest...   NaN
# 3                                                NaN   NaN
# 4  S-Collect Fundusz Inwestycyjny Zamknięty Niest...   NaN
# 5                                                NaN   NaN
#
# ...
